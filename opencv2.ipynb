# %%
import cv2    
import numpy as np
from matplotlib import pyplot as plt 
# %matplotlib inline

# %%
img = cv2.imread('opencv-logo2.png')
img1 = cv2.imread('messi5.jpg')

# %%
img.shape
# Out:
# (739, 600, 3)

# %%
x,y,z = img1.shape

# %%
img = img[:x,:y,:]

# %%
img.shape
# Out:
# (342, 548, 3)

# %%
img1.shape
# Out:
# (342, 548, 3)

# %%
plt.imshow(cv2.add(img,img1))

# %%
img2 = cv2.addWeighted(img,0.3,img1,0.7,0)

# %%
plt.imshow(img2)
